# %%
import os
from dotenv import load_dotenv
from pathlib import Path

NOTEBOOK_PATH = Path().resolve()
dotenv_path = NOTEBOOK_PATH / "postgres.env"
load_dotenv(dotenv_path)

DBHOST = os.environ.get("DBHOST")
DBPORT = os.environ.get("DBPORT")
DBUSER = os.environ.get("DBUSER")
DBNAME = os.environ.get("DBNAME")
DBPASS = os.environ.get("DBPASS")

IMG_DIRECTORY = NOTEBOOK_PATH / "imgs"
IMG_DIRECTORY.mkdir(exist_ok=True)

# %%
from sqlalchemy import create_engine, URL

engine_url = URL.create(
    drivername="postgresql+psycopg2",
    username=DBUSER,
    password=DBPASS,
    host=DBHOST,
    port=DBPORT,
    database=DBNAME,
)

engine = create_engine(url=engine_url)

# %%
import pandas as pd

query = """
            SELECT 
                p.name,
                p.latitude,
                p.longitude,
                d.year, 
                d.month, 
                d.day, 
                r.amount
            FROM rainfall r
            JOIN places p
            ON p.place_id = r.place_id
            JOIN dates d
            on r.date_id = d.date_id
            ;
        """

df = pd.read_sql(query, engine)

grouped_df = df.groupby(by=["year", "month", "name", "day"]).first()

to_drop = grouped_df[grouped_df.isna().any(axis=1)].index.get_level_values(2).unique()
for name in to_drop:
    grouped_df.drop(name, level='name', inplace=True)

# %%
year = 2019
month = 8

idx = pd.IndexSlice
test_df = grouped_df.loc[idx[year, month],].groupby(by=["name"]).agg({"latitude": "first", "longitude": "first", "amount":"sum" })

# %%
import geopandas as gpd

geo_df = gpd.GeoDataFrame(
    test_df,
    geometry=gpd.points_from_xy(test_df.longitude, test_df.latitude),
    crs="EPSG:4326"
)

geo_df.reset_index(inplace=True)

# %%
import folium
import folium.features

interactive_map = folium.Map(
    location=(11.934, 122.969),
    zoom_start=6,
    control_scale=True,
    tiles="https://mt1.google.com/vt/lyrs=r&x={x}&y={y}&z={z}",
    attr="Google maps",
)

popup = folium.GeoJsonPopup(
    fields=["name","amount"],
    aliases=["Station Name", "Rain Amount (mm)"],
    localize=True,
    labels=True,
    style="background-color: yellow;"
)

weather_stations = folium.features.GeoJson(
    geo_df,
    name="weather station",
    popup=popup
)

weather_stations.add_to(interactive_map)

interactive_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f875b82da268129a7e3911c53c7eebf9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             background-color: yellow;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f875b82da268129a7e3911c53c7eebf9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f875b82da268129a7e3911c53c7eebf9 = L.map(
#                 &quot;map_f875b82da268129a7e3911c53c7eebf9&quot;,
#                 {
#                     center: [11.934, 122.969],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_f875b82da268129a7e3911c53c7eebf9);
#
#
#
#
#
#             var tile_layer_c1a0bd23b89a8e629dfd394c2d7a4690 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=r\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google maps&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c1a0bd23b89a8e629dfd394c2d7a4690.addTo(map_f875b82da268129a7e3911c53c7eebf9);
#
#
#
#         function geo_json_71e870ab8e5ddad4cfee324e77002638_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_71e870ab8e5ddad4cfee324e77002638 = L.geoJson(null, {
#                 onEachFeature: geo_json_71e870ab8e5ddad4cfee324e77002638_onEachFeature,
#
#         });
#
#         function geo_json_71e870ab8e5ddad4cfee324e77002638_add (data) {
#             geo_json_71e870ab8e5ddad4cfee324e77002638
#                 .addData(data);
#         }
#             geo_json_71e870ab8e5ddad4cfee324e77002638_add({&quot;bbox&quot;: [118.758778, 6.057181, 126.337897, 20.801433], &quot;features&quot;: [{&quot;bbox&quot;: [122.017589, 14.105694, 122.017589, 14.105694], &quot;geometry&quot;: {&quot;coordinates&quot;: [122.017589, 14.105694], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;amount&quot;: 106.2, &quot;latitude&quot;: 14.105694, &quot;longitude&quot;: 122.017589, &quot;name&quot;: &quot;ALABAT, QUEZON&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [121.055244, 14.090081, 121.055244, 14.090081], &quot;geometry&quot;: {&quot;coordinates&quot;: [121.055244, 14.090081], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;amount&quot;: 323.0, &quot;latitude&quot;: 14.090081, &quot;longitude&quot;: 121.055244, &quot;name&quot;: &quot;AMBULONG, BATANGAS&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [121.630433, 18.359681, 121.630433, 18.359681], &quot;geometry&quot;: {&quot;coordinates&quot;: [121.630433, 18.359681], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;amount&quot;: 411.9, &quot;latitude&quot;: 18.359681, &quot;longitude&quot;: 121.630433, &quot;name&quot;: &quot;APARRI, CAGAYAN&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [120.601447, 16.4041, 120.601447, 16.4041], &quot;geometry&quot;: {&quot;coordinates&quot;: [120.601447, 16.4041], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;amount&quot;: 1525.2, &quot;latitude&quot;: 16.4041, &quot;longitude&quot;: 120.601447, &quot;name&quot;: &quot;BAGUIO CITY, BENGUET&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [121.632047, 15.749367, 121.632047, 15.749367], &quot;geometry&quot;: {&quot;coordinates&quot;: [121.632047, 15.749367], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {&quot;amount&quot;: 54.099999999999994, &quot;latitude&quot;: 15.749367, &quot;longitude&quot;: 121.632047, &quot;name&quot;: &quot;BALER, AURORA (RADAR)&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [121.970642, 20.427731, 121.970642, 20.427731], &quot;geometry&quot;: {&quot;coordinates&quot;: [121.970642, 20.427731], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;5&quot;, &quot;properties&quot;: {&quot;amount&quot;: 677.8000000000001, &quot;latitude&quot;: 20.427731, &quot;longitude&quot;: 121.970642, &quot;name&quot;: &quot;BASCO, BATANES&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [125.443639, 11.660908, 125.443639, 11.660908], &quot;geometry&quot;: {&quot;coordinates&quot;: [125.443639, 11.660908], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;6&quot;, &quot;properties&quot;: {&quot;amount&quot;: 113.2, &quot;latitude&quot;: 11.660908, &quot;longitude&quot;: 125.443639, &quot;name&quot;: &quot;BORONGAN, EASTERN SAMAR&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot

# %%
# rainfall_layer = folium.Choropleth(
#     geo_data=intrs,
#     data=intrs,
#     columns=("id", "amount"),
#     key_on="feature.id",

#     bins=9,
#     fill_color="viridis_r",
#     line_weight=0,
#     legend_name="Rainfall Amount (mm)"
# )

# rainfall_layer.add_to(interactive_map)

# def style_function(feature):
#     return {
#         "color": "transparent",
#         "fillColor": "transparent"
#     }

# tooltip = folium.features.GeoJsonTooltip(
#     fields=("amount",),
#     aliases=("Rainfall Amount (mm)",)
# )

# tooltip_layer = folium.features.GeoJson(
#     intrs,
#     style_function=style_function,
#     tooltip=tooltip
# )
# tooltip_layer.add_to(interactive_map)

# %%
interactive_map.save(IMG_DIRECTORY/ f"{year}-{month}-base-map.html")
